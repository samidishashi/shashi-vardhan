# %% [markdown]
# # Signal Processing Mid Term Project

# %% [markdown]
# # Introduction
# --------------
# The electrical activity of the heart recorded by electrodes placed on the body surface is called an ElectroCardioGram or ECG. These electrodes detect the electrical changes on the skin that are caused due to the heart muscles electrophysiologic pattern of depolarizing and repolarizing during each heartbeat.
#
# The ECG signals are widely used for diagnosis of heart diseases. An ECG record of a normal heart, called the normal sinus rhythm. It consists of a P wave, a QRS complex, and a T wave, caused by atrial depolarization, ventricular depolarization, and ventricular repolarization, respectively. Atrial repolarization is masked by the QRS complex and is not visible in the ECG
#
# We use electrocardiograph to perform electrocardiography, and produces the electrocardiogram.
#
# Now we are reading a ECG file and ploting it

# %%
# %matplotlib inline

import scipy as Sci
import scipy.linalg
import numpy as np
import pylab as pl
import matplotlib.pyplot as plt


f = open('aami3a.dat','rb')
AllSignal = np.fromfile(f,count=-1,dtype=np.uint16)
print('\n The length of the file is: ' + str(len(AllSignal)))
plt.plot(AllSignal[:43081])

plt.title('ECG signal sampled at 750Hz')
plt.xlabel('samples')
plt.ylabel('amplitude')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
f.close()
p=max(AllSignal[:43081])
print(+p)
q=min(AllSignal[:43081])
print(+q)
r=find_peaks(AllSignal[:43081])
#myheartrate = (60 ./ (median(diff(AllSignal[:43081])) ./ 1000)#
# Out:
#  The length of the file is: 43081
# 2127
# 1979
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-b9488651d8a8> in <module>()
#      22 q=min(AllSignal[:43081])
#      23 print(+q)
# ---> 24 r=find_peaks(AllSignal[:43081])
#      25 #myheartrate = (60 ./ (median(diff(AllSignal[:43081])) ./ 1000)#
#
# NameError: name 'find_peaks' is not defined

# %%
findpeaks(cb(50061:52060), 'MinPeakDistance', 100, 'MinPeakHeight', 0.04)

# %% [markdown]
# If a person has an average heart rate 72 beats per minute.
#
#               =72/60
#
#               =1.2 beats per second
#
#               =1.2*5
#
#               =6
#
#               =6/1.2*10e-3
#
#              5000 samples

# %%
QRS =zeros(len(AllSignal[:43081]),1)
myqrs = np.median(QRS)
print(+myqrs)
x=np.diff(AllSignal[:43081])
z=np.median(x)
print(+x)
print(+z)
p=80/z
print(+p)
q=p/1000
print(+q)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-130fae47082f> in <module>()
# ----> 1 QRS =zeros(len(AllSignal[:43081]),1)
#       2 myqrs = np.median(QRS)
#       3 print(+myqrs)
#       4 x=np.diff(AllSignal[:43081])
#       5 z=np.median(x)
#
# NameError: name 'zeros' is not defined

# %%
x=np.arange(0,5000/75e1,1/75e1)  
plt.plot(x,AllSignal[:5000])
plt.title('ECG signal sampled at 750Hz')
plt.xlabel('samples')
plt.ylabel('amplitude')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

# %% [markdown]
# #### DFT of the signal

# %%
HeartLine=AllSignal[:43081]
dataF=HeartLine-np.mean(HeartLine)
L=len(HeartLine)
f=np.arange(0,75e1/2,75e1/43081)
Y=np.fft.fft(dataF)
PyyClean=abs(Y)/L
plt.plot(f, PyyClean[:21541])
plt.title('DFT of the signal')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

# %%
from scipy import signal
import matplotlib.pyplot as pl
b, a = signal.butter(4,100,'high', analog=True)
w, h = signal.freqs(b,a,AllSignal[:43081])
plt.plot(w, 20*np.log10(abs(h)))
plt.xscale('log')
plt.title('Butterworth filter frequency response')
plt.xlabel('Frequency [radians / second]')
plt.ylabel('Amplitude [dB]')

# %%
b, a = scipy.signal.butter(4, 100, 'low', analog=True)
output_signal = scipy.signal.filtfilt(b, a, AllSignal[:5000])
plt.plot(output_signal)
