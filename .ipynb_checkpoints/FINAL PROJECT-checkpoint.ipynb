# %% [markdown]
# Introduction
# --------------

# %%
# %matplotlib inline
from skimage import novice, data, io, exposure
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import dicom

from scipy import ndimage
RefDs = dicom.read_file('im023.dcm')
print(RefDs)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'OTHER']
# (0008, 0012) Instance Creation Date              DA: '20070803'
# (0008, 0013) Instance Creation Time              TM: '152957.060000'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.5168.1900.305316949427703791868359949795
# (0008, 0020) Study Date                          DA: '20050924'
# (0008, 0021) Series Date                         DA: '20050924'
# (0008, 0023) Content Date                        DA: '20050924'
# (0008, 0030) Study Time                          TM: '121605'
# (0008, 0031) Series Time                         TM: '124945'
# (0008, 0033) Content Time                        TM: '124945'
# (0008, 0050) Accession Number                    SH: '1910853141496293'
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'MRI RT THIGH'
# (0008, 103e) Series Description                  LO: 'sag FSE/T2 Fatsat'
# (0008, 1090) Manufacturer's Model Name           LO: 'SIGNA EXCITE'
# (0010, 0010) Patient's Name                      PN: 'STS_011'
# (0010, 0020) Patient ID                          LO: 'STS_011'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064'
# (0012, 0064)  De-identification Method Code Sequence   7 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '113101'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Pixel Data Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113105'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Descriptors Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal With Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113108'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113109'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113111'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Safe Private Option'
#    ---------
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    UN: 'Soft-tissue-Sarcoma '
# (0013, 1013) Private tag data                    UN: '51681900'
# (0018, 0015) Body Part Examined                  CS: 'EXTREMITY'
# (0018, 0020) Scanning Sequence                   CS: 'SE'
# (0018, 0021) Sequence Variant                    CS: 'SK'
# (0018, 0022) Scan Options                        CS: ''
# (0018, 0023) MR Acquisition Type                 CS: ''
# (0018, 0050) Slice Thickness                     DS: '5'
# (0018, 0080) Repetition Time                     DS: ''
# (0018, 0081) Echo Time                           DS: ''
# (0018, 0091) Echo Train Length                   IS: ''
# (0018, 1000) Device Serial Number                LO: '0000000001016102'
# (0018, 1060) Trigger Time                        DS: ''
# (0018, 5100) Patient Position                    CS: 'FFS'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.5168.1900.211659248655092231923007628034
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.5168.1900.275802542059021701449696303567
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '12'
# (0020, 0013) Instance Number                     IS: '10'
# (0020, 0032) Image Position (Patient)            DS: ['-12.3182', '-224.741', '261.633']
# (0020, 0037) Image Orientation (Patient)         DS: ['-8.3346015e-2', '9.9652019e-1', '-9.7995078e-4', '1.2180652e-4', '-9.7318472e-4', '-9.9999952e-1']
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.5168.1900.238031984521120282175870528615
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: '29.345827'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0008) Number of Frames                    IS: '1'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.800800', '0.800800']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 9
# (0028, 0102) High Bit                            US: 8
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028, 1050) Window Center                       DS: '247'
# (0028, 1051) Window Width                        DS: '495'
# (3253, 0010) Private Creator                     LO: 'Varian Medical Systems VISION 3253'
# (7fe0, 0010) Pixel Data                          OW: Array of 524288 bytes

# %%
mrithigh = novice.open('im023.png')
mrithigh.show()

mrithigharray = mpimg.imread('im023.png','True') 
print('Original (9-bit encoding) the range is: '+str(np.max(mrithigharray))) 
bp=plt.subplot(221)
plt.imshow(mrithigharray)
Jm=exposure.rescale_intensity(mrithigharray,in_range=(0, pow(2,8)-1))
Km=exposure.rescale_intensity(mrithigharray,in_range=(0, pow(2,7)-1))
Lm=exposure.rescale_intensity(mrithigharray,in_range=(0, pow(2,5)-1)) 
plt.subplot(222)
plt.imshow(Jm)
plt.subplot(223)
plt.imshow(Km)
plt.subplot(224)
plt.imshow(Lm)
# Out:
# Original (9-bit encoding) the range is: 255

# %%
plt.figure()
ht=plt.hist(mrithigharray.ravel(), bins=256, histtype='step', color='red')
plt.figure()
ht=plt.hist(Jm.ravel(), bins=256, histtype='step', color='blue')
plt.figure()
ht=plt.hist(Km.ravel(), bins=256, histtype='step', color='green')
plt.figure()
ht=plt.hist(Lm.ravel(), bins=256, histtype='step', color='black')

# %%
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
img_eq = exposure.equalize_hist(mrithigharray)
plt.subplot(221)
plt.imshow(img_eq)
plt.subplot(222)
plt.imshow(mrithigharray)
plt.subplot(223)
ht=plt.hist(img_eq.ravel(), bins=256, histtype='step', color='blue')
plt.subplot(224)
ht=plt.hist(mrithigharray.ravel(), bins=256, histtype='step', color='blue')

# %%
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
p2, p98 = np.percentile(mrithigharray, (5, 70))
img_eq2 = exposure.rescale_intensity(mrithigharray, in_range=(p2, p98))

plt.subplot(221)
plt.imshow(img_eq2)
plt.subplot(222)
plt.imshow(mrithigharray)
plt.subplot(223)
ht=plt.hist(img_eq2.ravel(), bins=256, histtype='step', color='blue')
plt.subplot(224)
ht=plt.hist(mrithigharray.ravel(), bins=256, histtype='step', color='blue')

# %%
fig=plt.figure(figsize=(16, 12), dpi= 80, facecolor='w', edgecolor='k')
img_adapteq = exposure.equalize_adapthist(mrithigharray, clip_limit=0.08)

plt.subplot(221)
plt.imshow(img_adapteq)
plt.subplot(222)
plt.imshow(mrithigharray)
plt.subplot(223)
ht=plt.hist(img_eq2.ravel(), bins=256, histtype='step', color='blue')
plt.subplot(224)
ht=plt.hist(mrithigharray.ravel(), bins=256, histtype='step', color='blue')

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import ndimage


def plot(data, title):
    plot.i += 1
    plt.subplot(2,2,plot.i)
    plt.imshow(data)
    plt.gray()
    plt.title(title)
plot.i = 0


fig=plt.figure(figsize=(16, 12), dpi= 80, facecolor='w', edgecolor='k')
lowpass = ndimage.gaussian_filter(data, )
gauss_highpass = data-lowpass
plot(gauss_highpass, 'Gaussian Highpass, $\sigma = 7 pixels$' )
plt.show()

# %% [markdown]
# ## Summary

# %% [markdown]
# In this example we analyze the impact of reducing the encoding bits in an image on the rendering to the user.
#
# Your work for this example is:
#
# * Modify the clip limit in the Adaptive histogram equalization and observe the changes
# * Investigate the function equalize_adapthist and analyse the effect of the modification of clip limit according to the function description
#
# Comments and corrections welcome!

# %% [markdown]
# References
# ---------------
#
# * Tinku Acharya and Ajoy K. Ray, *Image Processing - Principles and Applications*. Wiley InterScience, 2006.
