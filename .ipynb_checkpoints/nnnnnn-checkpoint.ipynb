# %%
#we have first this command that initialize and matplotlib (library) for plotting and we specify that we want those plots inline in this notebook

# NOTE: IF YOU ARE EXECUTING FOR THE FIRST TIME RUN
# %matplotlib inline
# IF YOU ARE EXECUTING FOR THE SECOND TIME IN INTERACTIVE MODE RUN
#%matplotlib nbagg

#now we import different packages that will allow to do math, lineal algebra, numerical operations, array operations and plotting
import scipy as Sci
import scipy.linalg
import numpy as np
import pylab as pl
import matplotlib.pyplot as plt

#we use a simple open command for the file (basic Python)
f = open('UltrasoundSampleSignal.dat','rb')
#we read it using a numpy (therefore the np.) command that allows direct reading from file into an array
AllSignal = np.fromfile(f,count=-1,dtype=np.uint16)
#to verify the size of the file I am printing here the lenght of that array 
print('\n The length of the file is: ' + str(len(AllSignal)) + ' as expected from 15000 samples x 462 lines')
#we will now populate an array for the time which we now is 1/125MHz step for a total of 15000
x=np.arange(0,15000/125e6,1/125e6)  #start,stop,step
print('\n The length of the time array is: ' + str(len(x)) )
#now we plot only the first line acquired (15000 samples)
plt.plot(x,AllSignal[:15000])
plt.title('First Line Acquired')
plt.xlabel('Time')
plt.ylabel('Unsigned Integer Value')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
f.close() #close the file
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-383723e3fdd8> in <module>()
#      14
#      15 #we use a simple open command for the file (basic Python)
# ---> 16 f = open('UltrasoundSampleSignal.dat','rb')
#      17 #we read it using a numpy (therefore the np.) command that allows direct reading from file into an array
#      18 AllSignal = np.fromfile(f,count=-1,dtype=np.uint16)
#
# IOError: [Errno 2] No such file or directory: 'UltrasoundSampleSignal.dat'

# %% [markdown]
# Introduction
# --------------
#
# The Fourier Transform is one of the most powerful and well known tools to analyse frequency behaviour. As such, it allows performing many operations in signal and imaging processing such as filtering, signal evaluation, signal characterization, etc.
#
# In particular for medical applications some of the most widespread applications of Fourier Transform in signal processing are:
# 1. Filtering the signal to extract the information from the noise (i.e. the respiration rate will add important noise to an ECG signal but its frequency is much lower and can then be subtracted)
# 2. Evaluating the magnitude at specific frequencies of the signal to evaluate thresholds in an acquired signal (i.e. the detection of a seizure onset in EEG is characterized for large broadband signals)
# 3. The appearance of harmonics within a signal which may indicate there is an abnormality (i.e. the detection of harmonics in an ECG may indicate an arhytmia)
#
# Fourier transforms present important properties that allow to combine analysis in frequency with simplicity:
# 1. Linearity: the transform of a sum is the sum of the transforms
# 2. Symmetry: the transform of the negative frequency is the conjugate of the transform
# 3. Convolution: the transform of a convolution is the product of each transform
#
# In addition, filter design using frequency response is an important feature, and analysis of the response of a digital filter is usually done as a function of frequency:
# 1. It is often necessary to understand the behaviour of your signal before proposing the design of a filter
# 2. Once a filter is chosen, the impact of the order on the frequency behaviour of the filter and how that may affect the signal is important
#
# The Discrete Fourier Transform (DFT) is the primary analysis tool for Fourier Transform nowadays since much of the processing is performed on digitized signals.
#
# Using the DFT is equivalent to obtain a periodic signal out of a sequence (samples) of values.
#
# This notebook will show how the DFT is implemented on a signal and how we can detect the presence and main frequency components of noise within the signal as well as the main frequency of the signal of interest.
#
# We will work on an ultrasound signal that was acquired over time where some noise appears at some time point (we will determine when) and we will analyse the frequency component of the noise and the signal.
#
# Some specifics about this acquired file: we obtained 15000 samples with a frequency of sampling of 125MHz, then waited another trigger and repeated for a total of 462 times.
#
# We will also use this as an example on Python and simple signal analysis using Python.
#
# We will start by opening the binary file where the signal was stored in unsigned integer (16 bits) and reading all the data into an array:

# %%
#We continue plotting other lines (we will plot every line and there are 462) 
totlines=np.arange(462)
for index in totlines:
    Signal=AllSignal[index*15000:(index+1)*15000]
    plt.plot(x,AllSignal[index*15000:(index+1)*15000])
    plt.xlabel('Time')
    plt.ylabel('Unsigned Integer Value')
    plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

# %% [markdown]
# We can see from above that there are some lines that have noise.
#
# We will first analyse the frequency component of a clean and a noisy line.

# %%
#The first line is clear
FirstLine=AllSignal[:15000]

#But some lines are very noisy, for instance line 172
NoisyLine=AllSignal[174*15000:(174+1)*15000]

plt.subplots_adjust( hspace = .5 )
plt.subplot(211)
plt.plot(x,FirstLine)
plt.ylabel('Fist line - No noise')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.subplot(212)
plt.plot(x,NoisyLine)
plt.xlabel('Time')
plt.ylabel('Line 172-Noise')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

# %% [markdown]
# Now that we have a noisy and a clean line we will obtain the frequency component of those signals using DFT.
#
# First lets define the DFT:
#
# $$ A_k=\sum_{m=0}^{n-1}a_m \exp \left(-2\pi i \frac{mk}{n} \right ) [k=0,...,n-1] $$
#
# If we notice the signal has a dc component (not centered in zero) so unless we want to have a spectrum with a large value of dc or zero frequency we will first remove the dc component (by substracting the mean of the data).
#
# We will then obtain the DFT.

# %%
#we first eliminate dc
dataF=FirstLine-np.mean(FirstLine)
L=len(dataF)
#the frequencies after fft will be between 0 and 1/2 of the sampling frequency
f=np.arange(0,125e6/2,125e6/15000)
Y=np.fft.fft(dataF)
PyyClean=abs(Y)/L
#note: we are showing just L/2 elements which are the positive frequencies and we are normalizing
plt.subplot(121)
plt.plot(f, PyyClean[:7500])
plt.title('DFT of clean line')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
#Zooming into just less than 15MHz
inx=np.where(f>15e6)
inx=inx[0]
plt.subplot(122)
plt.plot(f[:inx[0]], PyyClean[:inx[0]])
plt.title('DFT of clean line')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

# %%
#now we repeat for the noisy line
#we first eliminate dc
dataN=NoisyLine-np.mean(NoisyLine)
L=len(dataN)
#the frequencies after fft will be between 0 and 1/2 of the sampling frequency
f=np.arange(0,125e6/2,125e6/15000)
Y=np.fft.fft(dataN)
PyyNoisy=abs(Y)/L
#note: we are showing just L/2 elements which are the positive frequencies and we are normalizing
plt.subplot(121)
plt.plot(f, PyyNoisy[:7500])
plt.title('DFT of noisy line')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
#Zooming into just less than 15MHz
inx=np.where(f>15e6)
inx=inx[0]
plt.subplot(122)
plt.plot(f[:inx[0]], PyyNoisy[:inx[0]])
plt.title('DFT of noisy line')
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

# %% [markdown]
# We can clearly see there are large noise peaks at various frequencies. These are actually harmonics of 1.5MHz and it is strong at 4.5MHz.
#
# We will use this here to determine a criteria for noise and later on to filter this signal.
#
# A nice tool: let's use interactive graph to "see" where those peaks are. For this, the backend for matplotlib to use is called nbagg so we will change the inline magic for **nbagg**.
#
# Go up in the code and change the magic command ```python %matplotlib inline``` for ```python %matplotlib nbagg``` and you will now be in **interactive mode**.
#
# **BEFORE YOU RUN** select the option "Kernel->Restart" or the rendering will fail.

# %% [markdown]
# ## Summary

# %% [markdown]
# In this example, we executed the Discrete Fourier Transform (DFT) on a clear and noisy signal.
#
# Test your knowdelge:
#
# Find which line(s) in the acquisition have a noticeable noise (we will define this point as when the noise peak at 4.5MHz reaches an amplitude in the FFT as high as the maximum in the clear line)
#     1. Use a loop in the code
#     2. Display all the line numbers that fall under this criteria
#     3. Display the amplitude of the peak at 4.5MHz for each noisy line
#
# Comments and corrections welcome!

# %% [markdown]
# References
# ---------------
#
# * Oppenheim, A. V., and A. S. Willsky. "Signals and Systems." Prentice-Hall, (1997).

# %% [markdown]
# # Assignment 1

# %% [markdown]
# To find noise threshold i.e amplitude of clean line at 4.5 MHz. we can find that peak using np.amax command.

# %%
x=np.amax(PyyClean)
print "Noise Threshold is  " + str(x)
# Out:
# Noise Threshold is  120.198226193

# %% [markdown]
# To find how many lines are noise we need to check how many lines exceeds noise threshold at 4.5 MHz.

# %%
totlines=np.arange(462)
i=0
for index in totlines:
    dataN=AllSignal[index*15000:(index+1)*15000]-np.mean(AllSignal[index*15000:(index+1)*15000])
    L=len(dataN)
    Y=np.fft.fft(dataN)
    Pyy=abs(Y)/L
    A=np.amax(Pyy)   #To find peak of Pyy 
    if A>120.2:     # Compare with 57.004
        i=i+1
        print "Line " +str(index) + "  has amplitude above noise threshold" 
        
print "Total Number of Noise lines are  " + str(i)
# Out:
# Line 74  has amplitude above noise threshold
# Line 75  has amplitude above noise threshold
# Line 83  has amplitude above noise threshold
# Line 84  has amplitude above noise threshold
# Line 85  has amplitude above noise threshold
# Line 86  has amplitude above noise threshold
# Line 87  has amplitude above noise threshold
# Line 88  has amplitude above noise threshold
# Line 89  has amplitude above noise threshold
# Line 90  has amplitude above noise threshold
# Line 91  has amplitude above noise threshold
# Line 92  has amplitude above noise threshold
# Line 93  has amplitude above noise threshold
# Line 94  has amplitude above noise threshold
# Line 95  has amplitude above noise threshold
# Line 96  has amplitude above noise threshold
# Line 97  has amplitude above noise threshold
# Line 98  has amplitude above noise threshold
# Line 99  has amplitude above noise threshold
# Line 100  has amplitude above noise threshold
# Line 101  has amplitude above noise threshold
# Line 102  has amplitude above noise threshold
# Line 103  has amplitude above noise threshold
# Line 104  has amplitude above noise threshold
# Line 105  has amplitude above noise threshold
# Line 106  has amplitude above noise threshold
# Line 107  has amplitude above noise threshold
# Line 108  has amplitude above noise threshold
# Line 109  has amplitude above noise threshold
# Line 110  has amplitude above noise threshold
# Line 111  has amplitude above noise threshold
# Line 112  has amplitude above noise threshold
# Line 113  has amplitude above noise threshold
# Line 114  has amplitude above noise threshold
# Line 115  has amplitude above noise threshold
# Line 116  has amplitude above noise threshold
# Line 117  has amplitude above noise threshold
# Line 149  has amplitude above noise threshold
# Line 150  has amplitude above noise threshold
# Line 151  has amplitude above noise threshold
# Line 152  has amplitude above noise threshold
# Line 153  has amplitude above noise threshold
# Line 154  has amplitude above noise threshold
# Line 155  has amplitude above noise threshold
# Line 156  has amplitude above noise threshold
# Line 157  has amplitude above noise threshold
# Line 158  has amplitude above noise threshold
# Line 159  has amplitude above noise threshold
# Line 160  has amplitude above noise threshold
# Line 161  has amplitude above noise threshold
# Line 162  has amplitude above noise threshold
# Line 163  has amplitude above noise threshold
# Line 164  has amplitude above noise threshold
# Line 165  has amplitude above noise threshold
# Line 166  has amplitude above noise threshold
# Line 167  has amplitude above noise threshold
# Line 168  has amplitude above noise threshold
# Line 169  has amplitude above noise threshold
# Line 170  has amplitude above noise threshold
# Line 171  has amplitude above noise threshold
# Line 172  has amplitude above noise threshold
# Line 173  has amplitude above noise threshold
# Line 174  has amplitude above noise threshold
# Line 175  has amplitude above noise threshold
# Line 176  has amplitude above noise threshold
# Line 177  has amplitude above noise threshold
# Line 178  has amplitude above noise threshold
# Line 179  has amplitude above noise threshold
# Line 180  has amplitude above noise threshold
# Line 181  has amplitude above noise threshold
# Line 182  has amplitude above noise threshold
# Line 183  has amplitude above noise threshold
# Line 184  has amplitude above noise threshold
# Line 185  has amplitude above noise threshold
# Line 186  has amplitude above noise threshold
# Line 187  has amplitude above noise threshold
# Line 214  has amplitude above noise threshold
# Line 215  has amplitude above noise threshold
# Line 216  has amplitude above noise threshold
# Line 217  has amplitude above noise threshold
# Line 218  has amplitude above noise threshold
# Line 219  has amplitude above noise threshold
# Line 220  has amplitude above noise threshold
# Line 221  has amplitude above noise threshold
# Line 222  has amplitude above noise threshold
# Line 223  has amplitude above noise threshold
# Line 224  has amplitude above noise threshold
# Line 225  has amplitude above noise threshold
# Line 226  has amplitude above noise threshold
# Line 227  has amplitude above noise threshold
# Line 228  has amplitude above noise threshold
# Line 229  has amplitude above noise threshold
# Line 230  has amplitude above noise threshold
# Line 231  has amplitude above noise threshold
# Line 232  has amplitude above noise threshold
# Line 233  has amplitude above noise threshold
# Line 234  has amplitude above noise threshold
# Line 235  has amplitude above noise threshold
# Line 236  has amplitude above noise threshold
# Line 237  has amplitude above noise threshold
# Line 238  has amplitude above noise threshold
# Line 239  has amplitude above noise threshold
# Line 240  has amplitude above noise threshold
# Line 241  has amplitude above noise threshold
# Line 242  has amplitude above noise threshold
# Line 243  has amplitude above noise threshold
# Line 244  has amplitude above noise threshold
# Line 245  has amplitude above noise threshold
# Line 246  has amplitude above noise threshold
# Line 247  has amplitude above noise threshold
# Line 248  has amplitude above noise threshold
# Line 249  has amplitude above noise threshold
# Line 250  has amplitude above noise threshold
# Line 251  has amplitude above noise threshold
# Line 252  has amplitude above noise threshold
# Line 264  has amplitude above noise threshold
# Line 268  has amplitude above noise threshold
# Line 269  has amplitude above noise threshold
# Line 270  has amplitude above noise threshold
# Line 271  has amplitude above noise threshold
# Line 272  has amplitude above noise threshold
# Line 273  has amplitude above noise threshold
# Line 274  has amplitude above noise threshold
# Line 275  has amplitude above noise threshold
# Line 276  has amplitude above noise threshold
# Line 277  has amplitude above noise threshold
# Line 278  has amplitude above noise threshold
# Line 279  has amplitude above noise threshold
# Line 280  has amplitude above noise threshold
# Line 281  has amplitude above noise threshold
# Line 282  has amplitude above noise threshold
# Line 283  has amplitude above noise threshold
# Line 284  has amplitude above noise threshold
# Line 285  has amplitude above noise threshold
# Line 286  has amplitude above noise threshold
# Line 287  has amplitude above noise threshold
# Line 288  has amplitude above noise threshold
# Line 289  has amplitude above noise threshold
# Line 290  has amplitude above noise threshold
# Line 291  has amplitude above noise threshold
# Line 292  has amplitude above noise threshold
# Line 293  has amplitude above noise threshold
# Line 294  has amplitude above noise threshold
# Line 295  has amplitude above noise threshold
# Line 296  has amplitude above noise threshold
# Line 297  has amplitude above noise threshold
# Line 298  has amplitude above noise threshold
# Line 299  has amplitude above noise threshold
# Line 300  has amplitude above noise threshold
# Line 301  has amplitude above noise threshold
# Line 302  has amplitude above noise threshold
# Line 303  has amplitude above noise threshold
# Line 304  has amplitude above noise threshold
# Line 305  has amplitude above noise threshold
# Line 306  has amplitude above noise threshold
# Line 307  has amplitude above noise threshold
# Line 308  has amplitude above noise threshold
# Line 309  has amplitude above noise threshold
# Line 310  has amplitude above noise threshold
# Line 311  has amplitude above noise threshold
# Line 312  has amplitude above noise threshold
# Line 313  has amplitude above noise threshold
# Line 314  has amplitude above noise threshold
# Line 315  has amplitude above noise threshold
# Line 316  has amplitude above noise threshold
# Line 317  has amplitude above noise threshold
# Line 318  has amplitude above noise threshold
# Line 319  has amplitude above noise threshold
# Line 320  has amplitude above noise threshold
# Line 321  has amplitude above noise threshold
# Line 322  has amplitude above noise threshold
# Line 323  has amplitude above noise threshold
# Line 324  has amplitude above noise threshold
# Line 325  has amplitude above noise threshold
# Line 326  has amplitude above noise threshold
# Line 327  has amplitude above noise threshold
# Line 328  has amplitude above noise threshold
# Line 329  has amplitude above noise threshold
# Line 330  has amplitude above noise threshold
# Line 331  has amplitude above noise threshold
# Line 332  has amplitude above noise threshold
# Line 333  has amplitude above noise threshold
# Line 334  has amplitude above noise threshold
# Line 335  has amplitude above noise threshold
# Line 336  has amplitude above noise threshold
# Line 337  has amplitude above noise threshold
# Line 338  has amplitude above noise threshold
# Line 339  has amplitude above noise threshold
# Line 340  has amplitude above noise threshold
# Line 341  has amplitude above noise threshold
# Line 342  has amplitude above noise threshold
# Line 343  has amplitude above noise threshold
# Line 344  has amplitude above noise threshold
# Line 345  has amplitude above noise threshold
# Line 346  has amplitude above noise threshold
# Line 347  has amplitude above noise threshold
# Line 348  has amplitude above noise threshold
# Line 349  has amplitude above noise threshold
# Line 350  has amplitude above noise threshold
# Line 351  has amplitude above noise threshold
# Line 352  has amplitude above noise threshold
# Line 353  has amplitude above noise threshold
# Line 354  has amplitude above noise threshold
# Line 355  has amplitude above noise threshold
# Line 356  has amplitude above noise threshold
# Line 357  has amplitude above noise threshold
# Line 358  has amplitude above noise threshold
# Line 359  has amplitude above noise threshold
# Line 360  has amplitude above noise threshold
# Line 361  has amplitude above noise threshold
# Line 362  has amplitude above noise threshold
# Line 363  has amplitude above noise threshold
# Line 364  has amplitude above noise threshold
# Line 365  has amplitude above noise threshold
# Line 366  has amplitude above noise threshold
# Line 367  has amplitude above noise threshold
# Line 368  has amplitude above noise threshold
# Line 369  has amplitude above noise threshold
# Line 370  has amplitude above noise threshold
# Line 371  has amplitude above noise threshold
# Line 372  has amplitude above noise threshold
# Line 373  has amplitude above noise threshold
# Line 374  has amplitude above noise threshold
# Line 375  has amplitude above noise threshold
# Line 376  has amplitude above noise threshold
# Line 377  has amplitude above noise threshold
# Line 378  has amplitude above noise threshold
# Line 379  has amplitude above noise threshold
# Line 380  has amplitude above noise threshold
# Line 381  has amplitude above noise threshold
# Line 382  has amplitude above noise threshold
# Line 383  has amplitude above noise threshold
# Line 384  has amplitude above noise threshold
# Line 385  has amplitude above noise threshold
# Line 386  has amplitude above noise threshold
# Line 387  has amplitude above noise threshold
# Line 388  has amplitude above noise threshold
# Line 389  has amplitude above noise threshold
# Line 390  has amplitude above noise threshold
# Line 391  has amplitude above noise threshold
# Line 392  has amplitude above noise threshold
# Line 393  has amplitude above noise threshold
# Line 394  has amplitude above noise threshold
# Line 395  has amplitude above noise threshold
# Line 396  has amplitude above noise threshold
# Line 397  has amplitude above noise threshold
# Line 398  has amplitude above noise threshold
# Line 399  has amplitude above noise threshold
# Line 400  has amplitude above noise threshold
# Line 401  has amplitude above noise threshold
# Line 402  has amplitude above noise threshold
# Line 403  has amplitude above noise threshold
# Line 404  has amplitude above noise threshold
# Line 405  has amplitude above noise threshold
# Line 406  has amplitude above noise threshold
# Line 407  has amplitude above noise threshold
# Line 408  has amplitude above noise threshold
# Line 409  has amplitude above noise threshold
# Line 410  has amplitude above noise threshold
# Line 411  has amplitude above noise threshold
# Line 412  has amplitude above noise threshold
# Line 413  has amplitude above noise threshold
# Line 414  has amplitude above noise threshold
# Line 415  has amplitude above noise threshold
# Line 416  has amplitude above noise threshold
# Line 417  has amplitude above noise threshold
# Line 418  has amplitude above noise threshold
# Line 419  has amplitude above noise threshold
# Line 420  has amplitude above noise threshold
# Line 421  has amplitude above noise threshold
# Line 422  has amplitude above noise threshold
# Line 423  has amplitude above noise threshold
# Line 424  has amplitude above noise threshold
# Line 425  has amplitude above noise threshold
# Line 426  has amplitude above noise threshold
# Line 427  has amplitude above noise threshold
# Line 428  has amplitude above noise threshold
# Line 429  has amplitude above noise threshold
# Line 430  has amplitude above noise threshold
# Line 431  has amplitude above noise threshold
# Line 432  has amplitude above noise threshold
# Line 433  has amplitude above noise threshold
# Line 434  has amplitude above noise threshold
# Line 435  has amplitude above noise threshold
# Line 436  has amplitude above noise threshold
# Line 437  has amplitude above noise threshold
# Line 438  has amplitude above noise threshold
# Line 439  has amplitude above noise threshold
# Line 440  has amplitude above noise threshold
# Line 441  has amplitude above noise threshold
# Line 442  has amplitude above noise threshold
# Line 443  has amplitude above noise threshold
# Line 444  has amplitude above noise threshold
# Line 445  has amplitude above noise threshold
# Line 446  has amplitude above noise threshold
# Line 447  has amplitude above noise threshold
# Line 448  has amplitude above noise threshold
# Line 449  has amplitude above noise threshold
# Line 450  has amplitude above noise threshold
# Line 451  has amplitude above noise threshold
# Line 452  has amplitude above noise threshold
# Line 453  has amplitude above noise threshold
# Line 454  has amplitude above noise threshold
# Line 455  has amplitude above noise threshold
# Line 456  has amplitude above noise threshold
# Line 457  has amplitude above noise threshold
# Line 458  has amplitude above noise threshold
# Line 459  has amplitude above noise threshold
# Line 460  has amplitude above noise threshold
# Line 461  has amplitude above noise threshold
# Total Number of Noise lines are  310
